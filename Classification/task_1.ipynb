# %% [markdown]
# # Task - 1
#
#
#
# ## For this File Please Follow all the Comments mentioned in this Notebook and complete Till Missing value treatment.

# %% [markdown]
# ## 1. Basic Pandas Operations

# %%
# Import all the required Libraries

import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Read the dataset and display the head. You will get the output as mentioned below

# ______________________________
# ______________________________
df = pd.read_csv('train.csv', error_bad_lines=False)
df.head()
# Out:
#    Unnamed: 0     ID City_Code  Region_Code Accomodation_Type  \
# 0       27385  27386        C3           64             Owned
# 1       33499  33500        C3         2955             Owned
# 2        7997   7998        C1         1542            Rented
# 3       33032  33033       C26          772            Rented
# 4       30516  30517        C2         1510             Owned
#
#   Reco_Insurance_Type  Upper_Age  Lower_Age Is_Spouse Health Indicator  \
# 0          Individual         36         36        No               X1
# 1          Individual         66         66        No               X6
# 2          Individual         24         24        No              NaN
# 3          Individual         75         75        No               X1
# 4               Joint         59         58       Yes               X1
#
#   Holding_Policy_Duration  Holding_Policy_Type  Reco_Policy_Cat  \
# 0                     14+                  2.0               16
# 1                      10                  1.0               19
# 2                       3                  1.0               16
# 3                       1                  3.0               16
# 4                     14+                  4.0               17
#
#    Reco_Policy_Premium  Response
# 0              13320.0         0
# 1              16152.0         0
# 2               7310.0         0
# 3              15792.0         0
# 4              23673.0         0

# %%
# Check the shape of the dataframe

# ______________________________
# ______________________________
df.shape
# Out:
# (10000, 15)

# %%
# On the dataframe apply info() function and observe the Dtypes and Missing Values

# ______________________________
# ______________________________
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               10000 non-null  int64
#  1   ID                       10000 non-null  int64
#  2   City_Code                10000 non-null  object
#  3   Region_Code              10000 non-null  int64
#  4   Accomodation_Type        10000 non-null  object
#  5   Reco_Insurance_Type      10000 non-null  object
#  6   Upper_Age                10000 non-null  int64
#  7   Lower_Age                10000 non-null  int64
#  8   Is_Spouse                10000 non-null  object
#  9   Health Indicator         7671 non-null   object
#  10  Holding_Policy_Duration  5946 non-null   object
#  11  Holding_Policy_Type      5946 non-null   float64
#  12  Reco_Policy_Cat          10000 non-null  int64
#  13  Reco_Policy_Premium      10000 non-null  float64
#  14  Response                 10000 non-null  int64
# dtypes: float64(2), int64(7), object(6)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#          Unnamed: 0            ID   Region_Code     Upper_Age    Lower_Age  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.00000
# mean   25513.420300  25514.420300   1723.510900     44.765600     42.65650
# std    14789.327793  14789.327793   1416.809648     17.281705     17.31614
# min        7.000000      8.000000      1.000000     18.000000     16.00000
# 25%    12518.250000  12519.250000    517.000000     28.000000     27.00000
# 50%    25511.500000  25512.500000   1382.000000     44.000000     40.00000
# 75%    38329.750000  38330.750000   2637.000000     59.000000     57.00000
# max    50873.000000  50874.000000   6193.000000     75.000000     75.00000
#
#        Holding_Policy_Type  Reco_Policy_Cat  Reco_Policy_Premium      Response
# count          5946.000000     10000.000000         10000.000000  10000.000000
# mean              2.431719        15.090700         14182.681460      0.245900
# std               1.026051         6.350237          6538.837384      0.430641
# min               1.000000         1.000000          2280.000000      0.000000
# 25%               1.000000        12.000000          9278.400000      0.000000
# 50%               3.000000        17.000000         13214.000000      0.000000
# 75%               3.000000        20.000000         18070.000000      0.000000
# max               4.000000        22.000000         42256.000000      1.000000

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                    0
# ID                            0
# City_Code                     0
# Region_Code                   0
# Accomodation_Type             0
# Reco_Insurance_Type           0
# Upper_Age                     0
# Lower_Age                     0
# Is_Spouse                     0
# Health Indicator           2329
# Holding_Policy_Duration    4054
# Holding_Policy_Type        4054
# Reco_Policy_Cat               0
# Reco_Policy_Premium           0
# Response                      0
# dtype: int64

# %%
df.describe(include='all')
# Out:
#           Unnamed: 0            ID City_Code   Region_Code Accomodation_Type  \
# count   10000.000000  10000.000000     10000  10000.000000             10000
# unique           NaN           NaN        36           NaN                 2
# top              NaN           NaN        C1           NaN             Owned
# freq             NaN           NaN      1796           NaN              5509
# mean    25513.420300  25514.420300       NaN   1723.510900               NaN
# std     14789.327793  14789.327793       NaN   1416.809648               NaN
# min         7.000000      8.000000       NaN      1.000000               NaN
# 25%     12518.250000  12519.250000       NaN    517.000000               NaN
# 50%     25511.500000  25512.500000       NaN   1382.000000               NaN
# 75%     38329.750000  38330.750000       NaN   2637.000000               NaN
# max     50873.000000  50874.000000       NaN   6193.000000               NaN
#
#        Reco_Insurance_Type     Upper_Age    Lower_Age Is_Spouse  \
# count                10000  10000.000000  10000.00000     10000
# unique                   2           NaN          NaN         2
# top             Individual           NaN          NaN        No
# freq                  7956           NaN          NaN      8318
# mean                   NaN     44.765600     42.65650       NaN
# std                    NaN     17.281705     17.31614       NaN
# min                    NaN     18.000000     16.00000       NaN
# 25%                    NaN     28.000000     27.00000       NaN
# 50%                    NaN     44.000000     40.00000       NaN
# 75%                    NaN     59.000000     57.00000       NaN
# max                    NaN     75.000000     75.00000       NaN
#
#        Health Indicator Holding_Policy_Duration  Holding_Policy_Type  \
# count              7671                    5946          5946.000000
# unique                9                      15                  NaN
# top                  X1                     14+                  NaN
# freq               2559                     898                  NaN
# mean                NaN                     NaN             2.431719
# std                 NaN                     NaN             1.026051
# min                 NaN                     NaN             1.000000
# 25%                 NaN                     NaN             1.000000
# 50%                 NaN                     NaN             3.000000
# 75%                 NaN                     NaN             3.000000
# max                 NaN                     NaN             4.000000
#
#         Reco_Policy_Cat  Reco_Policy_Premium      Response
# count      10000.000000         10000.000000  10000.000000
# unique              NaN                  NaN           NaN
# top                 NaN                  NaN           NaN
# freq                NaN                  NaN           NaN
# mean          15.090700         14182.681460      0.245900
# std            6.350237          6538.837384      0.430641
# min            1.000000          2280.000000      0.000000
# 25%           12.000000          9278.400000      0.000000
# 50%           17.000000         13214.000000      0.000000
# 75%           20.000000         18070.000000      0.000000
# max           22.000000         42256.000000      1.000000

# %%
df=df.replace({'Holding_Policy_Duration':{'NaN':"14+"}},regex=True)

# %%
df['Holding_Policy_Duration'].describe()
# Out:
# count     5946
# unique      15
# top        14+
# freq       898
# Name: Holding_Policy_Duration, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               10000 non-null  int64
#  1   ID                       10000 non-null  int64
#  2   City_Code                10000 non-null  object
#  3   Region_Code              10000 non-null  int64
#  4   Accomodation_Type        10000 non-null  object
#  5   Reco_Insurance_Type      10000 non-null  object
#  6   Upper_Age                10000 non-null  int64
#  7   Lower_Age                10000 non-null  int64
#  8   Is_Spouse                10000 non-null  object
#  9   Health Indicator         7671 non-null   object
#  10  Holding_Policy_Duration  5946 non-null   object
#  11  Holding_Policy_Type      5946 non-null   float64
#  12  Reco_Policy_Cat          10000 non-null  int64
#  13  Reco_Policy_Premium      10000 non-null  float64
#  14  Response                 10000 non-null  int64
# dtypes: float64(2), int64(7), object(6)
# memory usage: 1.1+ MB

# %% [markdown]
# ## 2. Cleaning the Data

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                    0
# ID                            0
# City_Code                     0
# Region_Code                   0
# Accomodation_Type             0
# Reco_Insurance_Type           0
# Upper_Age                     0
# Lower_Age                     0
# Is_Spouse                     0
# Health Indicator           2329
# Holding_Policy_Duration    4054
# Holding_Policy_Type        4054
# Reco_Policy_Cat               0
# Reco_Policy_Premium           0
# Response                      0
# dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0     ID City_Code  Region_Code Accomodation_Type  \
# 0       27385  27386        C3           64             Owned
# 1       33499  33500        C3         2955             Owned
# 2        7997   7998        C1         1542            Rented
# 3       33032  33033       C26          772            Rented
# 4       30516  30517        C2         1510             Owned
#
#   Reco_Insurance_Type  Upper_Age  Lower_Age Is_Spouse Health Indicator  \
# 0          Individual         36         36        No               X1
# 1          Individual         66         66        No               X6
# 2          Individual         24         24        No              NaN
# 3          Individual         75         75        No               X1
# 4               Joint         59         58       Yes               X1
#
#   Holding_Policy_Duration  Holding_Policy_Type  Reco_Policy_Cat  \
# 0                     14+                  2.0               16
# 1                      10                  1.0               19
# 2                       3                  1.0               16
# 3                       1                  3.0               16
# 4                     14+                  4.0               17
#
#    Reco_Policy_Premium  Response
# 0              13320.0         0
# 1              16152.0         0
# 2               7310.0         0
# 3              15792.0         0
# 4              23673.0         0

# %%
# Impute the Null values in Health Indicator, Holding_Policy_Duration and Holding_Policy_Type

# ____________________________
cateogry_columns=df.select_dtypes(include=['object']).columns.tolist()
integer_columns=df.select_dtypes(include=['int64','float64']).columns.tolist()

# ____________________________
for column in df:
    if column=="Holding_Policy_Type":
        pass
    else:
        if df[column].isnull().any():
            if(column in cateogry_columns):
                df[column]=df[column].fillna(df[column].mode()[0])
            else:
                df[column]=df[column].fillna(df[column].mean())

# %%
df['Holding_Policy_Type'].value_counts()
df['Holding_Policy_Type']=df['Holding_Policy_Type'].fillna(3.0)

# %%
df
# Out:
#       Unnamed: 0     ID City_Code  Region_Code Accomodation_Type  \
# 0          27385  27386        C3           64             Owned
# 1          33499  33500        C3         2955             Owned
# 2           7997   7998        C1         1542            Rented
# 3          33032  33033       C26          772            Rented
# 4          30516  30517        C2         1510             Owned
# ...          ...    ...       ...          ...               ...
# 9995        5203   5204        C3           13             Owned
# 9996       35448  35449        C5         1477            Rented
# 9997       47253  47254        C1         2357             Owned
# 9998       42544  42545        C1         1443            Rented
# 9999        7864   7865        C7         1476             Owned
#
#      Reco_Insurance_Type  Upper_Age  Lower_Age Is_Spouse Health Indicator  \
# 0             Individual         36         36        No               X1
# 1             Individual         66         66        No               X6
# 2             Individual         24         24        No               X1
# 3             Individual         75         75        No               X1
# 4                  Joint         59         58       Yes               X1
# ...                  ...        ...        ...       ...              ...
# 9995               Joint         47         40       Yes               X5
# 9996          Individual         34         34        No               X1
# 9997          Individual         64         64        No               X1
# 9998          Individual         53         53        No               X5
# 9999               Joint         56         47       Yes               X2
#
#      Holding_Policy_Duration  Holding_Policy_Type  Reco_Policy_Cat  \
# 0                        14+                  2.0               16
# 1                         10                  1.0               19
# 2                          3                  1.0               16
# 3                          1                  3.0               16
# 4                        14+                  4.0               17
# ...                      ...                  ...              ...
# 9995                     14+                  3.0               19
# 9996                       6                  1.0                4
# 9997                       8                  2.0               19
# 9998                     14+                  3.0               13
# 9999                     14+                  3.0               10
#
#       Reco_Policy_Premium  Response
# 0                 13320.0         0
# 1                 16152.0         0
# 2                  7310.0         0
# 3                 15792.0         0
# 4                 23673.0         0
# ...                   ...       ...
# 9995              27840.0         1
# 9996              10560.0         0
# 9997              14716.0         0
# 9998              11664.0         0
# 9999              28752.0         0
#
# [10000 rows x 15 columns]

# %%
df['Holding_Policy_Duration']=df['Holding_Policy_Duration'].str.replace("+","")
# Out:
# <ipython-input-211-aa73b8ceb55c>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['Holding_Policy_Duration']=df['Holding_Policy_Duration'].str.replace("+","")

# %%
### Check again Holding_Policy_Duration is in object column convert that into int

# ____________________________
df['Holding_Policy_Duration'].astype(str).astype(int)
df['Holding_Policy_Duration'].unique()
# Out:
# array(['14', '10', '3', '1', '7', '13', '9', '8', '2', '4', '5', '11',
#        '6', '12'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               10000 non-null  int64
#  1   ID                       10000 non-null  int64
#  2   City_Code                10000 non-null  object
#  3   Region_Code              10000 non-null  int64
#  4   Accomodation_Type        10000 non-null  object
#  5   Reco_Insurance_Type      10000 non-null  object
#  6   Upper_Age                10000 non-null  int64
#  7   Lower_Age                10000 non-null  int64
#  8   Is_Spouse                10000 non-null  object
#  9   Health Indicator         10000 non-null  object
#  10  Holding_Policy_Duration  10000 non-null  object
#  11  Holding_Policy_Type      10000 non-null  float64
#  12  Reco_Policy_Cat          10000 non-null  int64
#  13  Reco_Policy_Premium      10000 non-null  float64
#  14  Response                 10000 non-null  int64
# dtypes: float64(2), int64(7), object(6)
# memory usage: 1.1+ MB

# %%
# Observe that ['Accomodation_Type','Reco_Insurance_Type','Is_Spouse'] 
# above these Object columns have two values - Yes and No

# ____________________________
print('Accomodation_Type : ',df['Accomodation_Type'].unique())
print('Reco_Insurance_Type : ',df['Reco_Insurance_Type'].unique())
print('Is_Spouse : ',df['Is_Spouse'].unique())
# ____________________________
# Out:
# Accomodation_Type :  ['Owned' 'Rented']
# Reco_Insurance_Type :  ['Individual' 'Joint']
# Is_Spouse :  ['No' 'Yes']

# %%
# Converting all the Yes to 1 and No to 0. 
df['Accomodation_Type'].replace(('Owned','Rented'), (1, 0), inplace=True)
df['Reco_Insurance_Type'].replace(('Individual','Joint'), (1, 0), inplace=True)
df['Is_Spouse'].replace(('Yes', 'No'), (1, 0), inplace=True)


# Write a for loop to iterate over the list given above
# For each feature use pandas 'apply()' to convert all the 'Yes' to 1 and 'No' to 0


# ______________________________
# ______________________________

# %%
# Now again having a look at all those columns to see if everything went well

# _________________________________
df.head()
# Out:
#    Unnamed: 0     ID City_Code  Region_Code  Accomodation_Type  \
# 0       27385  27386        C3           64                  1
# 1       33499  33500        C3         2955                  1
# 2        7997   7998        C1         1542                  0
# 3       33032  33033       C26          772                  0
# 4       30516  30517        C2         1510                  1
#
#    Reco_Insurance_Type  Upper_Age  Lower_Age  Is_Spouse Health Indicator  \
# 0                    1         36         36          0               X1
# 1                    1         66         66          0               X6
# 2                    1         24         24          0               X1
# 3                    1         75         75          0               X1
# 4                    0         59         58          1               X1
#
#   Holding_Policy_Duration  Holding_Policy_Type  Reco_Policy_Cat  \
# 0                      14                  2.0               16
# 1                      10                  1.0               19
# 2                       3                  1.0               16
# 3                       1                  3.0               16
# 4                      14                  4.0               17
#
#    Reco_Policy_Premium  Response
# 0              13320.0         0
# 1              16152.0         0
# 2               7310.0         0
# 3              15792.0         0
# 4              23673.0         0

# %%
# Observe that all those columns are now converted from Object to Int64

# ________________________________
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               10000 non-null  int64
#  1   ID                       10000 non-null  int64
#  2   City_Code                10000 non-null  object
#  3   Region_Code              10000 non-null  int64
#  4   Accomodation_Type        10000 non-null  int64
#  5   Reco_Insurance_Type      10000 non-null  int64
#  6   Upper_Age                10000 non-null  int64
#  7   Lower_Age                10000 non-null  int64
#  8   Is_Spouse                10000 non-null  int64
#  9   Health Indicator         10000 non-null  object
#  10  Holding_Policy_Duration  10000 non-null  object
#  11  Holding_Policy_Type      10000 non-null  float64
#  12  Reco_Policy_Cat          10000 non-null  int64
#  13  Reco_Policy_Premium      10000 non-null  float64
#  14  Response                 10000 non-null  int64
# dtypes: float64(2), int64(10), object(3)
# memory usage: 1.1+ MB

# %%
# Checking all the Object Dtypes - Here, these columns have more than 2 categories

# ______________________________
# ______________________________
df.select_dtypes(include=['object']).columns.tolist()
# Out:
# ['City_Code', 'Health Indicator', 'Holding_Policy_Duration']

# %%
# You can also do this to separate Object columns

# ____________________________
cat_col = df.select_dtypes(include=['object'])
cat_col
# Out:
#      City_Code Health Indicator Holding_Policy_Duration
# 0           C3               X1                      14
# 1           C3               X6                      10
# 2           C1               X1                       3
# 3          C26               X1                       1
# 4           C2               X1                      14
# ...        ...              ...                     ...
# 9995        C3               X5                      14
# 9996        C5               X1                       6
# 9997        C1               X1                       8
# 9998        C1               X5                      14
# 9999        C7               X2                      14
#
# [10000 rows x 3 columns]

# %%
# Lets just try to see what is happening Response. Check the output.

cat_col
# Out:
#      City_Code Health Indicator Holding_Policy_Duration
# 0           C3               X1                      14
# 1           C3               X6                      10
# 2           C1               X1                       3
# 3          C26               X1                       1
# 4           C2               X1                      14
# ...        ...              ...                     ...
# 9995        C3               X5                      14
# 9996        C5               X1                       6
# 9997        C1               X1                       8
# 9998        C1               X5                      14
# 9999        C7               X2                      14
#
# [10000 rows x 3 columns]

# %%
# Dropping unknown column

# Write the code here to drop unknown column and check dataframe shape

df.drop('Unnamed: 0', axis = 1, inplace = True)
#df.drop('ID', axis = 1, inplace = True)
df.shape
# Out:
# (10000, 14)

# %%
# Getting all the Object Dtypes
#df.select_dtypes(include=['object']).columns.tolist()
cat_col.head()
# Out:
#   City_Code Health Indicator Holding_Policy_Duration
# 0        C3               X1                      14
# 1        C3               X6                      10
# 2        C1               X1                       3
# 3       C26               X1                       1
# 4        C2               X1                      14

# %%
# Encoding the categorical features



# column names are (annoyingly) lost after OneHotEncoding
# (i.e. the dataframe is converted to a numpy ndarray)

# Write the code here to use 'encoder' to convert all the categorical columns to numerical representations
# Take extra care to convert encoded numpy array to dataframe and call that data fram 'df_encoded'

# ______________________________
# ______________________________


cat_col['City_Code'].replace(('C3','C1','C26','C2','C17','C4' ,'C16', 'C9','C23','C21','C6','C7','C11','C22','C15','C13', 'C8','C35','C29','C33','C10','C12', 'C19', 'C5' ,'C18','C14','C24','C27','C20','C34','C36','C25','C28','C32','C30','C31'), (3,1,26,2,17,4,16,9,23,21,6,7,11,22,15,13,8,35,29,33,10,12,19,5,18,14,24,27,20,34,36,25,28,32,30,31), inplace=True)
cat_col['Health Indicator'].replace(('X1','X6','X4','X2','X3','X5','X8','X7','X9'), (1,6,4,2,3,5,8,7,9), inplace=True)
cat_col['Holding_Policy_Duration'].replace(('14','10','3','1','7','13','9','8','2','4','5','11','6','12'), (14,10,3,1,7,13,9,8,2,4,5,11,6,12), inplace=True)
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\pandas\core\series.py:4509: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
# Concatinating the original data frame and onehot encoded dataframe
df = pd.concat([df, cat_col], axis=1)
df
# Out:
#          ID  City_Code  Region_Code  Accomodation_Type  Reco_Insurance_Type  \
# 0     27386         C3           64                  1                    1
# 1     33500         C3         2955                  1                    1
# 2      7998         C1         1542                  0                    1
# 3     33033        C26          772                  0                    1
# 4     30517         C2         1510                  1                    0
# ...     ...        ...          ...                ...                  ...
# 9995   5204         C3           13                  1                    0
# 9996  35449         C5         1477                  0                    1
# 9997  47254         C1         2357                  1                    1
# 9998  42545         C1         1443                  0                    1
# 9999   7865         C7         1476                  1                    0
#
#       Upper_Age  Lower_Age  Is_Spouse  Health Indicator  \
# 0            36         36          0                X1
# 1            66         66          0                X6
# 2            24         24          0                X1
# 3            75         75          0                X1
# 4            59         58          1                X1
# ...         ...        ...        ...               ...
# 9995         47         40          1                X5
# 9996         34         34          0                X1
# 9997         64         64          0                X1
# 9998         53         53          0                X5
# 9999         56         47          1                X2
#
#       Holding_Policy_Duration  Holding_Policy_Type  Reco_Policy_Cat  \
# 0                          14                  2.0               16
# 1                          10                  1.0               19
# 2                           3                  1.0               16
# 3                           1                  3.0               16
# 4                          14                  4.0               17
# ...                       ...                  ...              ...
# 9995                       14                  3.0               19
# 9996                        6                  1.0                4
# 9997                        8                  2.0               19
# 9998                       14                  3.0               13
# 9999                       14                  3.0               10
#
#       Reco_Policy_Premium  Response  City_Code  Health Indicator  \
# 0                 13320.0         0          3                 1
# 1                 16152.0         0          3                 6
# 2                  7310.0         0          1                 1
# 3                 15792.0         0         26                 1
# 4                 23673.0         0          2                 1
# ...                   ...       ...        ...               ...
# 9995              27840.0         1          3                 5
# 9996              10560.0         0          5                 1
# 9997              14716.0         0          1                 1
# 9998              11664.0         0          1                 5
# 9999              28752.0         0          7                 2
#
#       Holding_Policy_Duration
# 0                          14
# 1                          10
# 2                           3
# 3                           1
# 4                          14
# ...                       ...
# 9995                       14
# 9996                        6
# 9997                        8
# 9998                       14
# 9999                       14
#
# [10000 rows x 17 columns]

# %%
# Drop all the unwanted columns.
# Because we have already encoded them and added to main dataframe
df = df.select_dtypes(exclude=['object'])
df
# Out:
#          ID  Region_Code  Accomodation_Type  Reco_Insurance_Type  Upper_Age  \
# 0     27386           64                  1                    1         36
# 1     33500         2955                  1                    1         66
# 2      7998         1542                  0                    1         24
# 3     33033          772                  0                    1         75
# 4     30517         1510                  1                    0         59
# ...     ...          ...                ...                  ...        ...
# 9995   5204           13                  1                    0         47
# 9996  35449         1477                  0                    1         34
# 9997  47254         2357                  1                    1         64
# 9998  42545         1443                  0                    1         53
# 9999   7865         1476                  1                    0         56
#
#       Lower_Age  Is_Spouse  Holding_Policy_Type  Reco_Policy_Cat  \
# 0            36          0                  2.0               16
# 1            66          0                  1.0               19
# 2            24          0                  1.0               16
# 3            75          0                  3.0               16
# 4            58          1                  4.0               17
# ...         ...        ...                  ...              ...
# 9995         40          1                  3.0               19
# 9996         34          0                  1.0                4
# 9997         64          0                  2.0               19
# 9998         53          0                  3.0               13
# 9999         47          1                  3.0               10
#
#       Reco_Policy_Premium  Response  City_Code  Health Indicator  \
# 0                 13320.0         0          3                 1
# 1                 16152.0         0          3                 6
# 2                  7310.0         0          1                 1
# 3                 15792.0         0         26                 1
# 4                 23673.0         0          2                 1
# ...                   ...       ...        ...               ...
# 9995              27840.0         1          3                 5
# 9996              10560.0         0          5                 1
# 9997              14716.0         0          1                 1
# 9998              11664.0         0          1                 5
# 9999              28752.0         0          7                 2
#
#       Holding_Policy_Duration
# 0                          14
# 1                          10
# 2                           3
# 3                           1
# 4                          14
# ...                       ...
# 9995                       14
# 9996                        6
# 9997                        8
# 9998                       14
# 9999                       14
#
# [10000 rows x 14 columns]
